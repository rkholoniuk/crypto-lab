# %%
import json
import requests

from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, LSTM
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import mean_absolute_error

sns.set_palette('Set2')
# %matplotlib inline

# %%
#endpoint = 'https://min-api.cryptocompare.com/data/histoday'
#res = requests.get(endpoint + '?fsym=LTC&tsym=USD&limit=2000&date=2022-02-23&api_key=6a31e60d1528d9d9dafb1faa2540af41393829b6c1f9fc495e5df6fe553a9fa8')
res = requests.get('https://min-api.cryptocompare.com/data/histoday?fsym=BTC&tsym=USD&limit=2000&toTs=1614124800&api_key=6a31e60d1528d9d9dafb1faa2540af41393829b6c1f9fc495e5df6fe553a9fa8')
hist = pd.DataFrame(json.loads(res.content)['Data'])
hist = hist.set_index('time')
hist = hist.drop(columns="conversionType")
hist = hist.drop(columns="conversionSymbol")
hist.index = pd.to_datetime(hist.index, unit='s')

# %%
hist.tail()
# Out:
#                 high       low      open  volumefrom      volumeto     close
# time
# 2021-02-20  57528.16  54140.61  55933.47    52924.57  2.974873e+09  55900.84
# 2021-02-21  58348.75  55516.07  55900.84    33823.01  1.934006e+09  57469.95
# 2021-02-22  57540.74  48194.31  57469.95   130806.33  6.995162e+09  54121.17
# 2021-02-23  54164.35  44983.39  54121.17   165758.08  8.016451e+09  48898.70
# 2021-02-24  51399.55  47015.55  48898.70    58710.56  2.930760e+09  49648.79

# %%
target_col = 'close'

# %%
def train_test_split(df, test_size=0.1):
    split_row = len(df) - int(test_size * len(df))
    train_data = df.iloc[:split_row]
    test_data = df.iloc[split_row:]
    return train_data, test_data

# %%
train, test = train_test_split(hist, test_size=0.1)

# %% [markdown]
# ## Plot data

# %%
def line_plot(line1, line2, label1=None, label2=None, title='', lw=2):
    fig, ax = plt.subplots(1, figsize=(16, 9))
    ax.plot(line1, label=label1, linewidth=lw)
    ax.plot(line2, label=label2, linewidth=lw)
    ax.set_ylabel('price [USD]', fontsize=14)
    ax.set_title(title, fontsize=18)
    ax.legend(loc='best', fontsize=18);

# %%
line_plot(train[target_col], test[target_col], 'training', 'test', title='BTC')

# %% [markdown]
# ## LSTM

# %%
def normalise_zero_base(df):
    """ Normalise dataframe column-wise to reflect changes with respect to first entry. """
    print(df.iloc[0])
    return df / df.iloc[0]

def normalise_min_max(df):
    """ Normalise dataframe column-wise min/max. """
    return (df - df.min()) / (data.max() - df.min())

# %%
def extract_window_data(df, window_len=10, zero_base=True):
    """ Convert dataframe to overlapping sequences/windows of len `window_data`.
    
        :param window_len: Size of window
        :param zero_base: If True, the data in each window is normalised to reflect changes
            with respect to the first entry in the window (which is then always 0)
    """
    window_data = []
    for idx in range(len(df) - window_len):
        tmp = df[idx: (idx + window_len)].copy()
        if zero_base:
            tmp = normalise_zero_base(tmp)
        window_data.append(tmp.values)
    return np.array(window_data)

# %%
def prepare_data(df, target_col, window_len=10, zero_base=True, test_size=0.2):
    """ Prepare data for LSTM. """
    # train test split
    train_data, test_data = train_test_split(df, test_size=test_size)
    
    # extract window data
    X_train = extract_window_data(train_data, window_len, zero_base)
    X_test = extract_window_data(test_data, window_len, zero_base)
    
    # extract targets
    y_train = train_data[target_col][window_len:].values
    y_test = test_data[target_col][window_len:].values
 
    if zero_base:
        y_train = y_train / train_data[target_col][:-window_len].values - 1
        y_test = y_test / test_data[target_col][:-window_len].values - 1

    return train_data, test_data, X_train, X_test, y_train, y_test

# %%
def build_lstm_model(input_data, output_size, neurons=20, activ_func='linear',
                     dropout=0.25, loss='mae', optimizer='adam'):
    model = Sequential()

    model.add(LSTM(neurons, input_shape=(input_data.shape[1], input_data.shape[2])))
    model.add(Dropout(dropout))
    model.add(Dense(units=output_size))
    model.add(Activation(activ_func))

    model.compile(loss=loss, optimizer=optimizer)
    return model

# %%
np.random.seed(42)

# data params
window_len = 7
test_size = 0.1
zero_base = True

# model params
lstm_neurons = 20
epochs = 50
batch_size = 4
loss = 'mae'
dropout = 0.25
optimizer = 'adam'

# %%
train, test, X_train, X_test, y_train, y_test = prepare_data(
    hist, target_col, window_len=window_len, zero_base=zero_base, test_size=test_size)
# Out:
# high               231.06
# low                225.75
# open               226.20
# volumefrom       61762.93
# volumeto      14174313.31
# close              230.25
# Name: 2015-09-04 00:00:00, dtype: float64
# high               235.61
# low                228.29
# open               230.25
# volumefrom       48280.18
# volumeto      11253257.52
# close              233.67
# Name: 2015-09-05 00:00:00, dtype: float64
# high               243.64
# low                234.74
# open               233.67
# volumefrom       66271.08
# volumeto      15939620.21
# close              239.86
# Name: 2015-09-06 00:00:00, dtype: float64
# high               242.66
# low                237.49
# open               239.86
# volumefrom       57187.93
# volumeto      13744695.27
# close              239.58
# Name: 2015-09-07 00:00:00, dtype: float64
# high               246.38
# low                239.23
# open               239.58
# volumefrom       76353.97
# volumeto      18605471.98
# close              243.24
# Name: 2015-09-08 00:00:00, dtype: float64
# high               244.34
# low                236.49
# open               243.24
# volumefrom       69263.89
# volumeto      16636258.68
# close              237.41
# Name: 2015-09-09 00:00:00, dtype: float64
# high               240.63
# low                234.31
# open               237.41
# volumefrom       60537.22
# volumeto      14447606.84
# close              238.08
# Name: 2015-09-10 00:00:00, dtype: float64
# high               241.02
# low                237.38
# open               238.08
# volumefrom       45773.98
# volumeto      10992443.10
# close              239.90
# Name: 2015-09-11 00:00:00, dtype: float64
# high               240.32
# low                233.32
# open               239.90
# volumefrom       43773.90
# volumeto      10407178.60
# close              235.60
# Name: 2015-09-12 00:00:00, dtype: float64
# high               236.16
# low                228.28
# open               235.60
# volumefrom       51595.80
# volumeto      11983360.26
# close              230.19
# Name: 2015-09-13 00:00:00, dtype: float64
# high               232.64
# low                225.96
# open               230.19
# volumefrom       61097.39
# volumeto      14070910.12
# close              229.91
# Name: 2015-09-14 00:00:00, dtype: float64
# high               242.83
# low                228.03
# open               229.91
# volumefrom       49516.04
# volumeto      11425472.46
# close              229.53
# Name: 2015-09-15 00:00:00, dtype: float64
# high               230.89
# low                225.05
# open               229.53
# volumefrom       51913.10
# volumeto      11866728.14
# close              228.60
# Name: 2015-09-16 00:00:00, dtype: float64
# high               235.17
# low                227.95
# open               228.60
# volumefrom       56060.73
# volumeto      12975914.38
# close              232.72
# Name: 2015-09-17 00:00:00, dtype: float64
# high               234.69
# low                230.58
# open               232.72
# volumefrom       53168.52
# volumeto      12397851.98
# close              232.21
# Name: 2015-09-18 00:00:00, dtype: float64
# high              233.35
# low               230.21
# open              232.21
# volumefrom      34470.84
# volumeto      8004103.62
# close             231.11
# Name: 2015-09-19 00:00:00, dtype: float64
# high              232.67
# low               229.93
# open              231.11
# volumefrom      33153.05
# volumeto      7676869.88
# close             231.09
# Name: 2015-09-20 00:00:00, dtype: float64
# high               231.63
# low                225.00
# open               231.09
# volumefrom       53425.18
# volumeto      12180039.21
# close              226.33
# Name: 2015-09-21 00:00:00, dtype: float64
# high               233.24
# low                224.07
# open               226.33
# volumefrom       71545.59
# volumeto      16390021.59
# close              230.01
# Name: 2015-09-22 00:00:00, dtype: float64
# high               232.20
# low                228.50
# open               230.01
# volumefrom       43602.20
# volumeto      10064288.46
# close              229.89
# Name: 2015-09-23 00:00:00, dtype: float64
# high               235.84
# low                229.57
# open               229.89
# volumefrom       72124.09
# volumeto      16797644.60
# close              233.76
# Name: 2015-09-24 00:00:00, dtype: float64
# high               237.58
# low                232.70
# open               233.76
# volumefrom       61574.99
# volumeto      14510987.84
# close              235.03
# Name: 2015-09-25 00:00:00, dtype: float64
# high              235.71
# low               232.74
# open              235.03
# volumefrom      40288.81
# volumeto      9449846.08
# close             234.30
# Name: 2015-09-26 00:00:00, dtype: float64
# high              234.75
# low               231.84
# open              234.30
# volumefrom      36139.39
# volumeto      8429802.53
# close             232.50
# Name: 2015-09-27 00:00:00, dtype: float64
# high               240.39
# low                232.37
# open               232.50
# volumefrom       64274.87
# volumeto      15282768.65
# close              238.87
# Name: 2015-09-28 00:00:00, dtype: float64
# high               240.39
# low                234.80
# open               238.87
# volumefrom       57296.63
# volumeto      13637645.50
# close              236.71
# Name: 2015-09-29 00:00:00, dtype: float64
# high               237.83
# low                234.39
# open               236.71
# volumefrom       50515.18
# volumeto      11946864.90
# close              235.93
# Name: 2015-09-30 00:00:00, dtype: float64
# high               238.66
# low                234.70
# open               235.93
# volumefrom       52884.47
# volumeto      12534482.83
# close              237.05
# Name: 2015-10-01 00:00:00, dtype: float64
# high               238.45
# low                235.14
# open               237.05
# volumefrom       47941.60
# volumeto      11378441.69
# close              236.71
# Name: 2015-10-02 00:00:00, dtype: float64
# high               239.52
# low                236.07
# open               236.71
# volumefrom       43304.67
# volumeto      10338780.01
# close              238.58
# Name: 2015-10-03 00:00:00, dtype: float64
# high              277.58
# low               237.51
# open              238.58
# volumefrom      31854.49
# volumeto      7618430.27
# close             238.33
# Name: 2015-10-04 00:00:00, dtype: float64
# high               240.53
# low                236.41
# open               238.33
# volumefrom       61240.52
# volumeto      14631928.87
# close              240.15
# Name: 2015-10-05 00:00:00, dtype: float64
# high               247.61
# low                239.36
# open               240.15
# volumefrom       78843.88
# volumeto      19242190.45
# close              246.14
# Name: 2015-10-06 00:00:00, dtype: float64
# high               247.28
# low                241.65
# open               246.14
# volumefrom       62600.80
# volumeto      15363142.53
# close              242.98
# Name: 2015-10-07 00:00:00, dtype: float64
# high               244.79
# low                241.57
# open               242.98
# volumefrom       44153.62
# volumeto      10762328.45
# close              242.58
# Name: 2015-10-08 00:00:00, dtype: float64
# high              244.56
# low               241.34
# open              242.58
# volumefrom      40572.80
# volumeto      9897714.74
# close             244.04
# Name: 2015-10-09 00:00:00, dtype: float64
# high              245.93
# low               242.89
# open              244.04
# volumefrom      38960.98
# volumeto      9547124.76
# close             245.35
# Name: 2015-10-10 00:00:00, dtype: float64
# high               248.26
# low                244.47
# open               245.35
# volumefrom       41425.58
# volumeto      10232454.52
# close              247.65
# Name: 2015-10-11 00:00:00, dtype: float64
# high              248.02
# low               244.65
# open              247.65
# volumefrom      40389.34
# volumeto      9961674.07
# close             245.35
# Name: 2015-10-12 00:00:00, dtype: float64
# high               251.19
# low                243.11
# open               245.35
# volumefrom       74881.90
# volumeto      18553307.06
# close              248.78
# Name: 2015-10-13 00:00:00, dtype: float64
# high               255.06
# low                248.28
# open               248.78
# volumefrom       69581.72
# volumeto      17511356.73
# close              252.33
# Name: 2015-10-14 00:00:00, dtype: float64
# high               256.76
# low                251.17
# open               252.33
# volumefrom       60635.46
# volumeto      15465023.84
# close              254.44
# Name: 2015-10-15 00:00:00, dtype: float64
# high               267.27
# low                253.93
# open               254.44
# volumefrom       95178.55
# volumeto      24886162.93
# close              262.87
# Name: 2015-10-16 00:00:00, dtype: float64
# high               275.41
# low                261.74
# open               262.87
# volumefrom      113842.13
# volumeto      30715446.42
# close              269.58
# Name: 2015-10-17 00:00:00, dtype: float64
# high               272.44
# low                259.53
# open               269.58
# volumefrom       52264.98
# volumeto      13921233.73
# close              261.67
# Name: 2015-10-18 00:00:00, dtype: float64
# high               265.95
# low                259.89
# open               261.67
# volumefrom       58169.97
# volumeto      15352671.06
# close              263.82
# Name: 2015-10-19 00:00:00, dtype: float64
# high               272.12
# low                262.70
# open               263.82
# volumefrom       75401.79
# volumeto      20200355.34
# close              269.75
# Name: 2015-10-20 00:00:00, dtype: float64
# high               272.17
# low                263.54
# open               269.75
# volumefrom       59638.03
# volumeto      16006977.10
# close              267.11
# Name: 2015-10-21 00:00:00, dtype: float64
# high               278.74
# low                266.80
# open               267.11
# volumefrom       93154.36
# volumeto      25481882.58
# close              274.42
# Name: 2015-10-22 00:00:00, dtype: float64
# high               279.77
# low                273.17
# open               274.42
# volumefrom       69321.79
# volumeto      19221822.38
# close              276.92
# Name: 2015-10-23 00:00:00, dtype: float64
# high               283.05
# low                277.01
# open               276.92
# volumefrom       60132.74
# volumeto      16875626.47
# close              282.56
# Name: 2015-10-24 00:00:00, dtype: float64
# high               295.56
# low                281.75
# open               282.56
# volumefrom      113901.26
# volumeto      32946170.24
# close              287.86
# Name: 2015-10-25 00:00:00, dtype: float64
# high               287.62
# low                279.62
# open               287.86
# volumefrom       73205.79
# volumeto      20794049.79
# close              285.15
# Name: 2015-10-26 00:00:00, dtype: float64
# high               298.43
# low                285.09
# open               285.15
# volumefrom      105868.30
# volumeto      31003938.20
# close              294.66
# Name: 2015-10-27 00:00:00, dtype: float64
# high               307.46
# low                294.02
# open               294.66
# volumefrom      116408.66
# volumeto      35117112.66
# close              303.54
# Name: 2015-10-28 00:00:00, dtype: float64
# high               318.48
# low                300.16
# open               303.54
# volumefrom      138919.55
# volumeto      43194878.81
# close              313.63
# Name: 2015-10-29 00:00:00, dtype: float64
# high               334.92
# low                310.82
# open               313.63
# volumefrom      156489.02
# volumeto      50796456.31
# close              327.12
# Name: 2015-10-30 00:00:00, dtype: float64
# high               333.25
# low                304.60
# open               327.12
# volumefrom      105831.92
# volumeto      33762428.44
# close              311.24
# Name: 2015-10-31 00:00:00, dtype: float64
# high               324.34
# low                304.72
# open               311.24
# volumefrom       73712.79
# volumeto      23427549.60
# close              322.95
# Name: 2015-11-01 00:00:00, dtype: float64
# high               365.75
# low                319.75
# open               322.95
# volumefrom      223094.73
# volumeto      76864059.45
# close              359.28
# Name: 2015-11-02 00:00:00, dtype: float64
# high          4.167800e+02
# low           3.545800e+02
# open          3.592800e+02
# volumefrom    4.219929e+05
# volumeto      1.634816e+08
# close         3.964900e+02
# Name: 2015-11-03 00:00:00, dtype: float64
# high          4.928000e+02
# low           3.686200e+02
# open          3.964900e+02
# volumefrom    5.177339e+05
# volumeto      2.296730e+08
# close         4.008900e+02
# Name: 2015-11-04 00:00:00, dtype: float64
# high          4.472400e+02
# low           3.660800e+02
# open          4.008900e+02
# volumefrom    3.029531e+05
# volumeto      1.217637e+08
# close         3.827000e+02
# Name: 2015-11-05 00:00:00, dtype: float64
# high               396.35
# low                348.84
# open               382.70
# volumefrom      255274.81
# volumeto      94921694.02
# close              369.81
# Name: 2015-11-06 00:00:00, dtype: float64
# high               391.75
# low                368.98
# open               369.81
# volumefrom      103025.55
# volumeto      39495095.00
# close              385.09
# Name: 2015-11-07 00:00:00, dtype: float64
# high               389.78
# low                365.49
# open               385.09
# volumefrom       94356.82
# volumeto      35907981.64
# close              371.56
# Name: 2015-11-08 00:00:00, dtype: float64
# high               385.11
# low                360.17
# open               371.56
# volumefrom      125535.36
# volumeto      47074440.94
# close              380.22
# Name: 2015-11-09 00:00:00, dtype: float64
# high               381.38
# low                323.21
# open               380.22
# volumefrom      210288.65
# volumeto      74896052.37
# close              336.69
# Name: 2015-11-10 00:00:00, dtype: float64
# high               341.76
# low                292.38
# open               336.69
# volumefrom      263962.67
# volumeto      83078426.53
# close              304.71
# Name: 2015-11-11 00:00:00, dtype: float64
# high               346.13
# low                306.07
# open               304.71
# volumefrom      164613.86
# volumeto      54120828.19
# close              333.85
# Name: 2015-11-12 00:00:00, dtype: float64
# high               341.79
# low                323.91
# open               333.85
# volumefrom       97247.84
# volumeto      32480298.94
# close              333.77
# Name: 2015-11-13 00:00:00, dtype: float64
# high               369.80
# low                326.35
# open               333.77
# volumefrom       71109.30
# volumeto      23836097.89
# close              331.77
# Name: 2015-11-14 00:00:00, dtype: float64
# high               334.78
# low                314.16
# open               331.77
# volumefrom       88318.89
# volumeto      28640663.53
# close              317.45
# Name: 2015-11-15 00:00:00, dtype: float64
# high               332.01
# low                314.06
# open               317.45
# volumefrom       87141.33
# volumeto      28260517.56
# close              330.21
# Name: 2015-11-16 00:00:00, dtype: float64
# high               342.91
# low                328.15
# open               330.21
# volumefrom       98247.88
# volumeto      32944787.48
# close              333.91
# Name: 2015-11-17 00:00:00, dtype: float64
# high               337.39
# low                329.42
# open               333.91
# volumefrom       78355.69
# volumeto      26194853.26
# close              335.92
# Name: 2015-11-18 00:00:00, dtype: float64
# high               335.64
# low                323.36
# open               335.92
# volumefrom       86374.86
# volumeto      28543062.16
# close              324.98
# Name: 2015-11-19 00:00:00, dtype: float64
# high               327.06
# low                309.48
# open               324.98
# volumefrom      109984.76
# volumeto      35090324.43
# close              321.12
# Name: 2015-11-20 00:00:00, dtype: float64
# high               328.42
# low                318.37
# open               321.12
# volumefrom       44997.78
# volumeto      14652996.70
# close              324.70
# Name: 2015-11-21 00:00:00, dtype: float64
# high               326.94
# low                319.35
# open               324.70
# volumefrom       36748.64
# volumeto      11915632.14
# close              322.78
# Name: 2015-11-22 00:00:00, dtype: float64
# high               325.00
# low                319.89
# open               322.78
# volumefrom       42733.54
# volumeto      13839023.95
# close              322.12
# Name: 2015-11-23 00:00:00, dtype: float64
# high               323.26
# low                315.54
# open               322.12
# volumefrom       50660.16
# volumeto      16282941.39
# close              318.35
# Name: 2015-11-24 00:00:00, dtype: float64
# high               330.04
# low                315.69
# open               318.35
# volumefrom       77684.42
# volumeto      25200934.79
# close              327.52
# Name: 2015-11-25 00:00:00, dtype: float64
# high               368.92
# low                327.40
# open               327.52
# volumefrom      211376.80
# volumeto      73395832.57
# close              353.74
# Name: 2015-11-26 00:00:00, dtype: float64
# high               363.90
# low                345.15
# open               353.74
# volumefrom      103479.86
# volumeto      36955394.20
# close              359.52
# Name: 2015-11-27 00:00:00, dtype: float64
# high               360.08
# low                350.49
# open               359.52
# volumefrom       56171.07
# volumeto      19988111.49
# close              355.83
# Name: 2015-11-28 00:00:00, dtype: float64
# high               372.84
# low                354.55
# open               355.83
# volumefrom       67365.88
# volumeto      24546100.04
# close              370.84
# Name: 2015-11-29 00:00:00, dtype: float64
# high               382.56
# low                367.87
# open               370.84
# volumefrom      129767.07
# volumeto      48913368.38
# close              377.97
# Name: 2015-11-30 00:00:00, dtype: float64
# high               379.02
# low                353.66
# open               377.97
# volumefrom      111904.70
# volumeto      40821470.73
# close              361.80
# Name: 2015-12-01 00:00:00, dtype: float64
# high               363.43
# low                347.16
# open               361.80
# volumefrom       92449.73
# volumeto      32881089.02
# close              359.98
# Name: 2015-12-02 00:00:00, dtype: float64
# high               371.37
# low                355.47
# open               359.98
# volumefrom       87225.21
# volumeto      31673283.30
# close              360.31
# Name: 2015-12-03 00:00:00, dtype: float64
# high               363.95
# low                354.31
# open               360.31
# volumefrom       60548.44
# volumeto      21820610.20
# close              361.67
# Name: 2015-12-04 00:00:00, dtype: float64
# high               390.28
# low                361.50
# open               361.67
# volumefrom      115198.52
# volumeto      43438102.10
# close              386.69
# Name: 2015-12-05 00:00:00, dtype: float64
# high               402.19
# low                382.62
# open               386.69
# volumefrom      131856.64
# volumeto      52068577.43
# close              393.38
# Name: 2015-12-06 00:00:00, dtype: float64
# high               398.74
# low                381.69
# open               393.38
# volumefrom       96750.51
# volumeto      38102878.77
# close              394.28
# Name: 2015-12-07 00:00:00, dtype: float64
# high               411.07
# low                388.03
# open               394.28
# volumefrom       74361.57
# volumeto      29543120.08
# close              410.67
# Name: 2015-12-08 00:00:00, dtype: float64
# high               424.58
# low                403.26
# open               410.67
# volumefrom      147362.83
# volumeto      61289838.70
# close              416.00
# Name: 2015-12-09 00:00:00, dtype: float64
# high               420.36
# low                409.53
# open               416.00
# volumefrom       71661.75
# volumeto      29794270.99
# close              415.49
# Name: 2015-12-10 00:00:00, dtype: float64
# high               453.37
# low                413.72
# open               415.49
# volumefrom      175058.38
# volumeto      76433917.46
# close              449.83
# Name: 2015-12-11 00:00:00, dtype: float64
# high               467.71
# low                403.69
# open               449.83
# volumefrom      211440.71
# volumeto      91838640.61
# close              432.29
# Name: 2015-12-12 00:00:00, dtype: float64
# high               440.97
# low                420.76
# open               432.29
# volumefrom       64139.63
# volumeto      27898250.74
# close              434.69
# Name: 2015-12-13 00:00:00, dtype: float64
# high               449.45
# low                428.84
# open               434.69
# volumefrom      218923.82
# volumeto      97068568.78
# close              442.00
# Name: 2015-12-14 00:00:00, dtype: float64
# high               464.23
# low                440.72
# open               442.00
# volumefrom      107064.22
# volumeto      48912227.87
# close              462.65
# Name: 2015-12-15 00:00:00, dtype: float64
# high               465.16
# low                437.37
# open               462.65
# volumefrom      185221.17
# volumeto      84336145.39
# close              453.98
# Name: 2015-12-16 00:00:00, dtype: float64
# high               458.44
# low                447.29
# open               453.98
# volumefrom       64574.94
# volumeto      29344348.08
# close              455.53
# Name: 2015-12-17 00:00:00, dtype: float64
# high               466.12
# low                453.46
# open               455.53
# volumefrom       83409.95
# volumeto      38425211.05
# close              463.18
# Name: 2015-12-18 00:00:00, dtype: float64
# high               465.99
# low                452.33
# open               463.18
# volumefrom       61309.41
# volumeto      28327900.15
# close              461.20
# Name: 2015-12-19 00:00:00, dtype: float64
# high               462.76
# low                431.10
# open               461.20
# volumefrom      121531.64
# volumeto      54316484.95
# close              441.78
# Name: 2015-12-20 00:00:00, dtype: float64
# high               445.54
# low                423.99
# open               441.78
# volumefrom      121990.88
# volumeto      53270215.60
# close              437.59
# Name: 2015-12-21 00:00:00, dtype: float64
# high               443.22
# low                433.25
# open               437.59
# volumefrom       65785.54
# volumeto      28845536.39
# close              437.03
# Name: 2015-12-22 00:00:00, dtype: float64
# high               444.78
# low                434.28
# open               437.03
# volumefrom       63247.04
# volumeto      27877349.10
# close              442.43
# Name: 2015-12-23 00:00:00, dtype: float64
# high               460.62
# low                441.76
# open               442.43
# volumefrom       79604.01
# volumeto      36096662.15
# close              452.98
# Name: 2015-12-24 00:00:00, dtype: float64
# high               457.44
# low                449.52
# open               452.98
# volumefrom       42390.82
# volumeto      19251958.85
# close              454.05
# Name: 2015-12-25 00:00:00, dtype: float64
# high               456.48
# low                400.45
# open               454.05
# volumefrom      208582.27
# volumeto      88564770.72
# close              415.37
# Name: 2015-12-26 00:00:00, dtype: float64
# high               425.51
# low                406.09
# open               415.37
# volumefrom       67581.91
# volumeto      28259303.48
# close              422.39
# Name: 2015-12-27 00:00:00, dtype: float64
# high               429.85
# low                417.14
# open               422.39
# volumefrom       68345.44
# volumeto      28978639.73
# close              421.76
# Name: 2015-12-28 00:00:00, dtype: float64
# high               433.56
# low                419.30
# open               421.76
# volumefrom       70645.37
# volumeto      30163445.65
# close              431.92
# Name: 2015-12-29 00:00:00, dtype: float64
# high               435.04
# low                420.77
# open               431.92
# volumefrom       68269.90
# volumeto      29289416.54
# close              427.15
# Name: 2015-12-30 00:00:00, dtype: float64
# high               433.12
# low                417.14
# open               427.15
# volumefrom       65213.47
# volumeto      27758278.73
# close              429.95
# Name: 2015-12-31 00:00:00, dtype: float64
# high               437.95
# low                425.86
# open               429.95
# volumefrom       46973.12
# volumeto      20334286.58
# close              433.99
# Name: 2016-01-01 00:00:00, dtype: float64
# high               437.43
# low                430.73
# open               433.99
# volumefrom       33570.39
# volumeto      14566820.95
# close              433.72
# Name: 2016-01-02 00:00:00, dtype: float64
# high               434.14
# low                423.09
# open               433.72
# volumefrom       54826.26
# volumeto      23490162.61
# close              430.70
# Name: 2016-01-03 00:00:00, dtype: float64
# high               435.26
# low                428.60
# open               430.70
# volumefrom       53007.87
# volumeto      22943968.22
# close              433.32
# Name: 2016-01-04 00:00:00, dtype: float64
# high               435.25
# low                428.87
# open               433.32
# volumefrom       45029.87
# volumeto      19499588.99
# close              431.20
# Name: 2016-01-05 00:00:00, dtype: float64
# high               432.11
# low                425.00
# open               431.20
# volumefrom       43432.03
# volumeto      18702334.67
# close              430.82
# Name: 2016-01-06 00:00:00, dtype: float64
# high               457.54
# low                428.52
# open               430.82
# volumefrom      130197.44
# volumeto      58253615.03
# close              457.05
# Name: 2016-01-07 00:00:00, dtype: float64
# high               462.92
# low                446.51
# open               457.05
# volumefrom       91304.61
# volumeto      41594025.32
# close              452.87
# Name: 2016-01-08 00:00:00, dtype: float64
# high               454.55
# low                444.90
# open               452.87
# volumefrom       39809.95
# volumeto      17967113.95
# close              448.31
# Name: 2016-01-09 00:00:00, dtype: float64
# high               448.88
# low                438.62
# open               448.31
# volumefrom       44457.28
# volumeto      19778456.68
# close              446.19
# Name: 2016-01-10 00:00:00, dtype: float64
# high               451.08
# low                441.77
# open               446.19
# volumefrom       56587.40
# volumeto      25358480.83
# close              447.72
# Name: 2016-01-11 00:00:00, dtype: float64
# high               448.41
# low                443.14
# open               447.72
# volumefrom       44585.93
# volumeto      19913400.66
# close              445.04
# Name: 2016-01-12 00:00:00, dtype: float64
# high               443.72
# low                420.39
# open               445.04
# volumefrom       92040.06
# volumeto      39525195.32
# close              432.18
# Name: 2016-01-13 00:00:00, dtype: float64
# high               433.74
# low                427.01
# open               432.18
# volumefrom       46172.51
# volumeto      19948730.59
# close              429.13
# Name: 2016-01-14 00:00:00, dtype: float64
# high          4.301500e+02
# low           3.647100e+02
# open          4.291300e+02
# volumefrom    2.681417e+05
# volumeto      1.070606e+08
# close         3.722600e+02
# Name: 2016-01-15 00:00:00, dtype: float64
# high               386.72
# low                350.39
# open               372.26
# volumefrom      183962.03
# volumeto      68297105.65
# close              385.04
# Name: 2016-01-16 00:00:00, dtype: float64
# high               390.72
# low                377.71
# open               385.04
# volumefrom       66089.34
# volumeto      25464382.40
# close              382.47
# Name: 2016-01-17 00:00:00, dtype: float64
# high               387.29
# low                373.21
# open               382.47
# volumefrom       69301.33
# volumeto      26546465.91
# close              384.40
# Name: 2016-01-18 00:00:00, dtype: float64
# high               386.69
# low                375.89
# open               384.40
# volumefrom       66345.24
# volumeto      25417876.87
# close              379.46
# Name: 2016-01-19 00:00:00, dtype: float64
# high               425.72
# low                374.05
# open               379.46
# volumefrom      190316.94
# volumeto      76873917.15
# close              414.58
# Name: 2016-01-20 00:00:00, dtype: float64
# high               423.42
# low                403.86
# open               414.58
# volumefrom       89938.22
# volumeto      37264942.18
# close              410.24
# Name: 2016-01-21 00:00:00, dtype: float64
# high               411.49
# low                374.90
# open               410.24
# volumefrom      144856.97
# volumeto      56548790.09
# close              382.65
# Name: 2016-01-22 00:00:00, dtype: float64
# high               395.43
# low                380.27
# open               382.65
# volumefrom       61383.14
# volumeto      23908533.75
# close              388.61
# Name: 2016-01-23 00:00:00, dtype: float64
# high               405.40
# low                385.53
# open               388.61
# volumefrom       64535.73
# volumeto      25770175.58
# close              402.13
# Name: 2016-01-24 00:00:00, dtype: float64
# high               403.78
# low                386.85
# open               402.13
# volumefrom       67659.06
# volumeto      26793044.72
# close              392.76
# Name: 2016-01-25 00:00:00, dtype: float64
# high               397.74
# low                387.90
# open               392.76
# volumefrom       56805.12
# volumeto      22384754.50
# close              389.78
# Name: 2016-01-26 00:00:00, dtype: float64
# high               397.37
# low                389.35
# open               389.78
# volumefrom       43678.72
# volumeto      17297117.36
# close              395.02
# Name: 2016-01-27 00:00:00, dtype: float64
# high               395.42
# low                376.71
# open               395.02
# volumefrom       77319.55
# volumeto      29717813.05
# close              379.69
# Name: 2016-01-28 00:00:00, dtype: float64
# high               385.75
# low                363.49
# open               379.69
# volumefrom      138455.81
# volumeto      51927041.84
# close              380.29
# Name: 2016-01-29 00:00:00, dtype: float64
# high               381.75
# low                375.04
# open               380.29
# volumefrom       36179.60
# volumeto      13720656.84
# close              377.76
# Name: 2016-01-30 00:00:00, dtype: float64
# high               380.54
# low                366.88
# open               377.76
# volumefrom       39019.71
# volumeto      14718855.75
# close              369.84
# Name: 2016-01-31 00:00:00, dtype: float64
# high               379.78
# low                365.27
# open               369.84
# volumefrom       74346.01
# volumeto      27728088.91
# close              372.18
# Name: 2016-02-01 00:00:00, dtype: float64
# high               376.63
# low                371.40
# open               372.18
# volumefrom       50981.07
# volumeto      19123252.48
# close              373.92
# Name: 2016-02-02 00:00:00, dtype: float64
# high               375.89
# low                366.20
# open               373.92
# volumefrom       59813.05
# volumeto      22266682.14
# close              368.02
# Name: 2016-02-03 00:00:00, dtype: float64
# high               391.83
# low                368.05
# open               368.02
# volumefrom      101868.70
# volumeto      38961905.49
# close              390.65
# Name: 2016-02-04 00:00:00, dtype: float64
# high               391.15
# low                384.48
# open               390.65
# volumefrom       60917.35
# volumeto      23688228.07
# close              386.46
# Name: 2016-02-05 00:00:00, dtype: float64
# high               386.35
# low                372.87
# open               386.46
# volumefrom       78850.10
# volumeto      29801286.80
# close              376.68
# Name: 2016-02-06 00:00:00, dtype: float64
# high               382.61
# low                375.28
# open               376.68
# volumefrom       40743.17
# volumeto      15395728.35
# close              377.94
# Name: 2016-02-07 00:00:00, dtype: float64
# high               380.92
# low                372.10
# open               377.94
# volumefrom       62236.23
# volumeto      23424062.52
# close              372.63
# Name: 2016-02-08 00:00:00, dtype: float64
# high               377.59
# low                371.42
# open               372.63
# volumefrom       55358.89
# volumeto      20801701.37
# close              375.32
# Name: 2016-02-09 00:00:00, dtype: float64
# high               385.38
# low                374.09
# open               375.32
# volumefrom       97487.81
# volumeto      37137791.06
# close              381.88
# Name: 2016-02-10 00:00:00, dtype: float64
# high               383.23
# low                372.75
# open               381.88
# volumefrom       62653.08
# volumeto      23858467.37
# close              379.45
# Name: 2016-02-11 00:00:00, dtype: float64
# high               386.40
# low                379.32
# open               379.45
# volumefrom       53759.93
# volumeto      20685663.27
# close              384.04
# Name: 2016-02-12 00:00:00, dtype: float64
# high               392.57
# low                383.31
# open               384.04
# volumefrom       48158.05
# volumeto      18757146.48
# close              390.10
# Name: 2016-02-13 00:00:00, dtype: float64
# high               405.93
# low                390.06
# open               390.10
# volumefrom       73589.64
# volumeto      29442484.67
# close              405.50
# Name: 2016-02-14 00:00:00, dtype: float64
# high               410.85
# low                396.56
# open               405.50
# volumefrom       86127.28
# volumeto      34862753.81
# close              401.07
# Name: 2016-02-15 00:00:00, dtype: float64
# high               409.75
# low                398.00
# open               401.07
# volumefrom       68330.32
# volumeto      27726590.05
# close              406.42
# Name: 2016-02-16 00:00:00, dtype: float64
# high               421.45
# low                405.05
# open               406.42
# volumefrom       90323.21
# volumeto      37559686.21
# close              417.14
# Name: 2016-02-17 00:00:00, dtype: float64
# high               425.51
# low                414.78
# open               417.14
# volumefrom       77346.22
# volumeto      32541108.12
# close              421.40
# Name: 2016-02-18 00:00:00, dtype: float64
# high               424.26
# low                416.36
# open               421.40
# volumefrom       52240.27
# volumeto      21991480.98
# close              419.98
# Name: 2016-02-19 00:00:00, dtype: float64
# high               442.66
# low                419.49
# open               419.98
# volumefrom      111626.76
# volumeto      48500793.67
# close              440.06
# Name: 2016-02-20 00:00:00, dtype: float64
# high               447.61
# low                425.47
# open               440.06
# volumefrom      100499.03
# volumeto      44120520.96
# close              437.87
# Name: 2016-02-21 00:00:00, dtype: float64
# high               440.18
# low                431.30
# open               437.87
# volumefrom       56010.22
# volumeto      24563748.20
# close              437.79
# Name: 2016-02-22 00:00:00, dtype: float64
# high               440.76
# low                414.36
# open               437.79
# volumefrom       93717.62
# volumeto      39915706.29
# close              419.90
# Name: 2016-02-23 00:00:00, dtype: float64
# high               425.17
# low                410.36
# open               419.90
# volumefrom       66506.84
# volumeto      28041199.85
# close              422.72
# Name: 2016-02-24 00:00:00, dtype: float64
# high               427.18
# low                417.51
# open               422.72
# volumefrom       53541.45
# volumeto      22692099.41
# close              423.48
# Name: 2016-02-25 00:00:00, dtype: float64
# high               427.58
# low                419.11
# open               423.48
# volumefrom       53212.34
# volumeto      22642013.92
# close              427.32
# Name: 2016-02-26 00:00:00, dtype: float64
# high               434.14
# low                427.30
# open               427.32
# volumefrom       42792.33
# volumeto      18543436.43
# close              431.30
# Name: 2016-02-27 00:00:00, dtype: float64
# high               435.62
# low                421.22
# open               431.30
# volumefrom       50847.07
# volumeto      21876091.34
# close              432.47
# Name: 2016-02-28 00:00:00, dtype: float64
# high               441.32
# low                429.83
# open               432.47
# volumefrom       68773.52
# volumeto      30077319.62
# close              436.21
# Name: 2016-02-29 00:00:00, dtype: float64
# high               439.02
# low                428.49
# open               436.21
# volumefrom       67461.59
# volumeto      29312670.84
# close              434.04
# Name: 2016-03-01 00:00:00, dtype: float64
# high               435.91
# low                423.85
# open               434.04
# volumefrom       57744.55
# volumeto      24894311.79
# close              425.36
# Name: 2016-03-02 00:00:00, dtype: float64
# high               425.83
# low                414.94
# open               425.36
# volumefrom       78902.45
# volumeto      33188751.08
# close              419.56
# Name: 2016-03-03 00:00:00, dtype: float64
# high               423.39
# low                407.20
# open               419.56
# volumefrom       75267.61
# volumeto      31416610.30
# close              409.48
# Name: 2016-03-04 00:00:00, dtype: float64
# high               410.06
# low                386.93
# open               409.48
# volumefrom      129149.15
# volumeto      51725937.08
# close              399.00
# Name: 2016-03-05 00:00:00, dtype: float64
# high               412.02
# low                393.09
# open               399.00
# volumefrom       62593.92
# volumeto      25324456.27
# close              405.96
# Name: 2016-03-06 00:00:00, dtype: float64
# high               416.58
# low                401.98
# open               405.96
# volumefrom       61774.07
# volumeto      25349627.97
# close              414.87
# Name: 2016-03-07 00:00:00, dtype: float64
# high               416.72
# low                408.42
# open               414.87
# volumefrom       53769.80
# volumeto      22204517.93
# close              411.90
# Name: 2016-03-08 00:00:00, dtype: float64
# high               414.88
# low                408.94
# open               411.90
# volumefrom       50919.66
# volumeto      21035428.97
# close              412.76
# Name: 2016-03-09 00:00:00, dtype: float64
# high               417.48
# low                410.27
# open               412.76
# volumefrom       55735.81
# volumeto      23114636.62
# close              415.83
# Name: 2016-03-10 00:00:00, dtype: float64
# high               422.40
# low                415.11
# open               415.83
# volumefrom       60632.19
# volumeto      25469781.33
# close              419.11
# Name: 2016-03-11 00:00:00, dtype: float64
# high               420.67
# low                407.03
# open               419.11
# volumefrom       59635.49
# volumeto      24660321.63
# close              410.36
# Name: 2016-03-12 00:00:00, dtype: float64
# high               415.93
# low                409.57
# open               410.36
# volumefrom       34977.81
# volumeto      14457108.00
# close              412.41
# Name: 2016-03-13 00:00:00, dtype: float64
# high               416.08
# low                411.19
# open               412.41
# volumefrom       49332.82
# volumeto      20471909.73
# close              414.31
# Name: 2016-03-14 00:00:00, dtype: float64
# high               417.37
# low                412.31
# open               414.31
# volumefrom       48596.63
# volumeto      20227610.88
# close              415.13
# Name: 2016-03-15 00:00:00, dtype: float64
# high               416.95
# low                413.32
# open               415.13
# volumefrom       44535.24
# volumeto      18509954.18
# close              415.91
# Name: 2016-03-16 00:00:00, dtype: float64
# high               419.56
# low                415.33
# open               415.91
# volumefrom       43820.66
# volumeto      18409340.68
# close              418.16
# Name: 2016-03-17 00:00:00, dtype: float64
# high               418.58
# low                402.48
# open               418.16
# volumefrom       66068.03
# volumeto      27178165.73
# close              408.16
# Name: 2016-03-18 00:00:00, dtype: float64
# high               410.49
# low                402.13
# open               408.16
# volumefrom       36997.54
# volumeto      15084656.26
# close              408.69
# Name: 2016-03-19 00:00:00, dtype: float64
# high               413.45
# low                407.24
# open               408.69
# volumefrom       30543.21
# volumeto      12577521.63
# close              411.53
# Name: 2016-03-20 00:00:00, dtype: float64
# high               413.09
# low                407.25
# open               411.53
# volumefrom       43159.26
# volumeto      17735457.25
# close              411.11
# Name: 2016-03-21 00:00:00, dtype: float64
# high               417.94
# low                410.78
# open               411.11
# volumefrom       49075.11
# volumeto      20425092.47
# close              416.21
# Name: 2016-03-22 00:00:00, dtype: float64
# high               419.58
# low                414.18
# open               416.21
# volumefrom       40605.05
# volumeto      16946522.38
# close              416.98
# Name: 2016-03-23 00:00:00, dtype: float64
# high               417.68
# low                412.88
# open               416.98
# volumefrom       38828.43
# volumeto      16210672.62
# close              414.74
# Name: 2016-03-24 00:00:00, dtype: float64
# high               417.30
# low                412.41
# open               414.74
# volumefrom       34588.15
# volumeto      14431200.38
# close              415.71
# Name: 2016-03-25 00:00:00, dtype: float64
# high               417.71
# low                413.93
# open               415.71
# volumefrom       28056.64
# volumeto      11696306.67
# close              416.51
# Name: 2016-03-26 00:00:00, dtype: float64
# high               427.36
# low                415.50
# open               416.51
# volumefrom       61724.40
# volumeto      26137150.51
# close              424.57
# Name: 2016-03-27 00:00:00, dtype: float64
# high               425.36
# low                419.70
# open               424.57
# volumefrom       43444.76
# volumeto      18410749.99
# close              422.21
# Name: 2016-03-28 00:00:00, dtype: float64
# high               424.53
# low                406.36
# open               422.21
# volumefrom       69113.03
# volumeto      28765857.05
# close              415.00
# Name: 2016-03-29 00:00:00, dtype: float64
# high               416.22
# low                408.40
# open               415.00
# volumefrom       43282.31
# volumeto      17890792.61
# close              412.44
# Name: 2016-03-30 00:00:00, dtype: float64
# high               417.16
# low                411.45
# open               412.44
# volumefrom       41840.90
# volumeto      17407273.19
# close              415.66
# Name: 2016-03-31 00:00:00, dtype: float64
# high               416.86
# low                412.79
# open               415.66
# volumefrom       38218.91
# volumeto      15852511.01
# close              415.64
# Name: 2016-04-01 00:00:00, dtype: float64
# high               420.09
# low                415.09
# open               415.64
# volumefrom       31309.25
# volumeto      13137339.89
# close              418.51
# Name: 2016-04-02 00:00:00, dtype: float64
# high              420.18
# low               416.95
# open              418.51
# volumefrom      22798.16
# volumeto      9591214.82
# close             419.06
# Name: 2016-04-03 00:00:00, dtype: float64
# high               420.39
# low                416.21
# open               419.06
# volumefrom       33436.90
# volumeto      14031939.65
# close              419.33
# Name: 2016-04-04 00:00:00, dtype: float64
# high               423.67
# low                417.95
# open               419.33
# volumefrom       40886.78
# volumeto      17260368.39
# close              422.07
# Name: 2016-04-05 00:00:00, dtype: float64
# high               422.81
# low                419.54
# open               422.07
# volumefrom       32667.23
# volumeto      13836754.91
# close              421.26
# Name: 2016-04-06 00:00:00, dtype: float64
# high               422.03
# low                417.94
# open               421.26
# volumefrom       36056.99
# volumeto      15200495.86
# close              420.14
# Name: 2016-04-07 00:00:00, dtype: float64
# high               423.51
# low                415.50
# open               420.14
# volumefrom       46947.25
# volumeto      19810838.26
# close              417.69
# Name: 2016-04-08 00:00:00, dtype: float64
# high               418.85
# low                412.39
# open               417.69
# volumefrom       29424.60
# volumeto      12291880.83
# close              418.05
# Name: 2016-04-09 00:00:00, dtype: float64
# high              421.63
# low               416.69
# open              418.05
# volumefrom      23300.23
# volumeto      9806327.90
# close             420.25
# Name: 2016-04-10 00:00:00, dtype: float64
# high               422.35
# low                418.11
# open               420.25
# volumefrom       36387.29
# volumeto      15374195.04
# close              421.43
# Name: 2016-04-11 00:00:00, dtype: float64
# high               426.69
# low                420.70
# open               421.43
# volumefrom       57711.94
# volumeto      24580503.64
# close              424.74
# Name: 2016-04-12 00:00:00, dtype: float64
# high               426.58
# low                421.41
# open               424.74
# volumefrom       38088.60
# volumeto      16183793.93
# close              423.47
# Name: 2016-04-13 00:00:00, dtype: float64
# high               425.44
# low                421.84
# open               423.47
# volumefrom       30664.40
# volumeto      13038970.54
# close              424.02
# Name: 2016-04-14 00:00:00, dtype: float64
# high               429.49
# low                423.25
# open               424.02
# volumefrom       54119.98
# volumeto      23214560.10
# close              428.67
# Name: 2016-04-15 00:00:00, dtype: float64
# high               432.00
# low                426.84
# open               428.67
# volumefrom       29021.18
# volumeto      12517265.78
# close              430.05
# Name: 2016-04-16 00:00:00, dtype: float64
# high               430.62
# low                423.79
# open               430.05
# volumefrom       25586.86
# volumeto      10980868.31
# close              426.26
# Name: 2016-04-17 00:00:00, dtype: float64
# high               429.07
# low                424.35
# open               426.26
# volumefrom       32574.71
# volumeto      13951524.85
# close              427.69
# Name: 2016-04-18 00:00:00, dtype: float64
# high               436.07
# low                426.84
# open               427.69
# volumefrom       45675.40
# volumeto      19713466.34
# close              434.92
# Name: 2016-04-19 00:00:00, dtype: float64
# high               442.86
# low                432.51
# open               434.92
# volumefrom       74361.53
# volumeto      32655415.81
# close              441.16
# Name: 2016-04-20 00:00:00, dtype: float64
# high               450.80
# low                439.53
# open               441.16
# volumefrom       63127.80
# volumeto      28168774.29
# close              449.34
# Name: 2016-04-21 00:00:00, dtype: float64
# high               450.19
# low                441.90
# open               449.34
# volumefrom       49710.33
# volumeto      22225157.27
# close              445.28
# Name: 2016-04-22 00:00:00, dtype: float64
# high               451.48
# low                443.07
# open               445.28
# volumefrom       42358.77
# volumeto      18998211.55
# close              450.08
# Name: 2016-04-23 00:00:00, dtype: float64
# high               461.78
# low                447.89
# open               450.08
# volumefrom       74434.28
# volumeto      33984269.34
# close              457.56
# Name: 2016-04-24 00:00:00, dtype: float64
# high               466.23
# low                451.79
# open               457.56
# volumefrom       81656.03
# volumeto      37614684.81
# close              461.73
# Name: 2016-04-25 00:00:00, dtype: float64
# high               468.86
# low                459.23
# open               461.73
# volumefrom       67557.86
# volumeto      31451239.15
# close              466.00
# Name: 2016-04-26 00:00:00, dtype: float64
# high               467.87
# low                444.62
# open               466.00
# volumefrom       90806.31
# volumeto      41539684.76
# close              447.01
# Name: 2016-04-27 00:00:00, dtype: float64
# high               450.10
# low                433.90
# open               447.01
# volumefrom       81934.58
# volumeto      36369788.38
# close              448.48
# Name: 2016-04-28 00:00:00, dtype: float64
# high               456.31
# low                445.22
# open               448.48
# volumefrom       44850.72
# volumeto      20264761.95
# close              454.98
# Name: 2016-04-29 00:00:00, dtype: float64
# high               456.86
# low                446.65
# open               454.98
# volumefrom       35308.40
# volumeto      15994805.53
# close              448.53
# Name: 2016-04-30 00:00:00, dtype: float64
# high              454.21
# low               447.52
# open              448.53
# volumefrom      21745.59
# volumeto      9838490.74
# close             452.24
# Name: 2016-05-01 00:00:00, dtype: float64
# high               453.87
# low                440.21
# open               452.24
# volumefrom       73854.48
# volumeto      32863011.95
# close              444.18
# Name: 2016-05-02 00:00:00, dtype: float64
# high               451.54
# low                441.55
# open               444.18
# volumefrom       49749.84
# ...
# close         1.879203e+04
# Name: 2020-12-01 00:00:00, dtype: float64
# high          1.933716e+04
# low           1.835000e+04
# open          1.879203e+04
# volumefrom    4.778781e+04
# volumeto      9.038178e+08
# close         1.922619e+04
# Name: 2020-12-02 00:00:00, dtype: float64
# high          1.960849e+04
# low           1.888812e+04
# open          1.922619e+04
# volumefrom    3.869987e+04
# volumeto      7.470888e+08
# close         1.944844e+04
# Name: 2020-12-03 00:00:00, dtype: float64
# high          1.954162e+04
# low           1.860379e+04
# open          1.944844e+04
# volumefrom    4.223435e+04
# volumeto      8.043665e+08
# close         1.866500e+04
# Name: 2020-12-04 00:00:00, dtype: float64
# high          1.917840e+04
# low           1.851492e+04
# open          1.866500e+04
# volumefrom    2.051748e+04
# volumeto      3.884669e+08
# close         1.915684e+04
# Name: 2020-12-05 00:00:00, dtype: float64
# high          1.941733e+04
# low           1.888588e+04
# open          1.915684e+04
# volumefrom    2.117250e+04
# volumeto      4.057086e+08
# close         1.937894e+04
# Name: 2020-12-06 00:00:00, dtype: float64
# high          1.941151e+04
# low           1.890997e+04
# open          1.937894e+04
# volumefrom    2.490846e+04
# volumeto      4.773346e+08
# close         1.918141e+04
# Name: 2020-12-07 00:00:00, dtype: float64
# high          1.929538e+04
# low           1.822731e+04
# open          1.918141e+04
# volumefrom    4.615165e+04
# volumeto      8.665434e+08
# close         1.832352e+04
# Name: 2020-12-08 00:00:00, dtype: float64
# high          1.863924e+04
# low           1.766915e+04
# open          1.832352e+04
# volumefrom    5.799745e+04
# volumeto      1.057335e+09
# close         1.854992e+04
# Name: 2020-12-09 00:00:00, dtype: float64
# high          1.855432e+04
# low           1.792056e+04
# open          1.854992e+04
# volumefrom    3.750096e+04
# volumeto      6.848028e+08
# close         1.825047e+04
# Name: 2020-12-10 00:00:00, dtype: float64
# high          1.829510e+04
# low           1.759813e+04
# open          1.825047e+04
# volumefrom    4.516617e+04
# volumeto      8.093189e+08
# close         1.803486e+04
# Name: 2020-12-11 00:00:00, dtype: float64
# high          1.894878e+04
# low           1.803305e+04
# open          1.803486e+04
# volumefrom    2.615036e+04
# volumeto      4.842395e+08
# close         1.881498e+04
# Name: 2020-12-12 00:00:00, dtype: float64
# high          1.941465e+04
# low           1.873367e+04
# open          1.881498e+04
# volumefrom    3.090288e+04
# volumeto      5.920218e+08
# close         1.916905e+04
# Name: 2020-12-13 00:00:00, dtype: float64
# high          1.933960e+04
# low           1.900122e+04
# open          1.916905e+04
# volumefrom    2.382771e+04
# volumeto      4.568411e+08
# close         1.927469e+04
# Name: 2020-12-14 00:00:00, dtype: float64
# high          1.955323e+04
# low           1.906006e+04
# open          1.927469e+04
# volumefrom    4.233140e+04
# volumeto      8.198393e+08
# close         1.944196e+04
# Name: 2020-12-15 00:00:00, dtype: float64
# high          2.152736e+04
# low           1.929986e+04
# open          1.944196e+04
# volumefrom    9.537474e+04
# volumeto      1.949841e+09
# close         2.135213e+04
# Name: 2020-12-16 00:00:00, dtype: float64
# high          2.369898e+04
# low           2.124041e+04
# open          2.135213e+04
# volumefrom    1.404831e+05
# volumeto      3.194654e+09
# close         2.282217e+04
# Name: 2020-12-17 00:00:00, dtype: float64
# high          2.327154e+04
# low           2.234587e+04
# open          2.282217e+04
# volumefrom    5.965848e+04
# volumeto      1.362468e+09
# close         2.313557e+04
# Name: 2020-12-18 00:00:00, dtype: float64
# high          2.411451e+04
# low           2.275503e+04
# open          2.313557e+04
# volumefrom    5.391152e+04
# volumeto      1.268054e+09
# close         2.384472e+04
# Name: 2020-12-19 00:00:00, dtype: float64
# high          2.425216e+04
# low           2.309572e+04
# open          2.384472e+04
# volumefrom    4.298199e+04
# volumeto      1.014225e+09
# close         2.346706e+04
# Name: 2020-12-20 00:00:00, dtype: float64
# high          2.407770e+04
# low           2.201591e+04
# open          2.346706e+04
# volumefrom    7.593438e+04
# volumeto      1.750627e+09
# close         2.272713e+04
# Name: 2020-12-21 00:00:00, dtype: float64
# high          2.383323e+04
# low           2.237826e+04
# open          2.272713e+04
# volumefrom    4.968546e+04
# volumeto      1.149767e+09
# close         2.382332e+04
# Name: 2020-12-22 00:00:00, dtype: float64
# high          2.408298e+04
# low           2.264137e+04
# open          2.382332e+04
# volumefrom    6.616163e+04
# volumeto      1.552021e+09
# close         2.323950e+04
# Name: 2020-12-23 00:00:00, dtype: float64
# high          2.377856e+04
# low           2.271645e+04
# open          2.323950e+04
# volumefrom    3.980423e+04
# volumeto      9.238485e+08
# close         2.372420e+04
# Name: 2020-12-24 00:00:00, dtype: float64
# high          2.477664e+04
# low           2.341743e+04
# open          2.372420e+04
# volumefrom    4.965515e+04
# volumeto      1.199895e+09
# close         2.470798e+04
# Name: 2020-12-25 00:00:00, dtype: float64
# high          2.678061e+04
# low           2.449427e+04
# open          2.470798e+04
# volumefrom    6.292313e+04
# volumeto      1.611548e+09
# close         2.644570e+04
# Name: 2020-12-26 00:00:00, dtype: float64
# high          2.834008e+04
# low           2.580596e+04
# open          2.644570e+04
# volumefrom    9.105209e+04
# volumeto      2.463391e+09
# close         2.624927e+04
# Name: 2020-12-27 00:00:00, dtype: float64
# high          2.746163e+04
# low           2.608596e+04
# open          2.624927e+04
# volumefrom    5.202749e+04
# volumeto      1.402006e+09
# close         2.703945e+04
# Name: 2020-12-28 00:00:00, dtype: float64
# high          2.738360e+04
# low           2.586425e+04
# open          2.703945e+04
# volumefrom    5.547749e+04
# volumeto      1.479551e+09
# close         2.736078e+04
# Name: 2020-12-29 00:00:00, dtype: float64
# high          2.899020e+04
# low           2.736009e+04
# open          2.736078e+04
# volumefrom    7.075288e+04
# volumeto      1.993722e+09
# close         2.888961e+04
# Name: 2020-12-30 00:00:00, dtype: float64
# high          2.930167e+04
# low           2.795713e+04
# open          2.888961e+04
# volumefrom    6.691503e+04
# volumeto      1.924969e+09
# close         2.897240e+04
# Name: 2020-12-31 00:00:00, dtype: float64
# high          2.966633e+04
# low           2.874821e+04
# open          2.897240e+04
# volumefrom    5.084173e+04
# volumeto      1.487306e+09
# close         2.938894e+04
# Name: 2021-01-01 00:00:00, dtype: float64
# high          3.325729e+04
# low           2.903626e+04
# open          2.938894e+04
# volumefrom    1.192148e+05
# volumeto      3.750441e+09
# close         3.220364e+04
# Name: 2021-01-02 00:00:00, dtype: float64
# high          3.478934e+04
# low           3.201059e+04
# open          3.220364e+04
# volumefrom    9.351099e+04
# volumeto      3.132759e+09
# close         3.306348e+04
# Name: 2021-01-03 00:00:00, dtype: float64
# high          3.362270e+04
# low           2.849329e+04
# open          3.306348e+04
# volumefrom    1.249097e+05
# volumeto      3.901979e+09
# close         3.203055e+04
# Name: 2021-01-04 00:00:00, dtype: float64
# high          3.448744e+04
# low           2.998529e+04
# open          3.203055e+04
# volumefrom    9.373547e+04
# volumeto      3.037657e+09
# close         3.403829e+04
# Name: 2021-01-05 00:00:00, dtype: float64
# high          3.697376e+04
# low           3.340420e+04
# open          3.403829e+04
# volumefrom    1.081907e+05
# volumeto      3.788317e+09
# close         3.684986e+04
# Name: 2021-01-06 00:00:00, dtype: float64
# high          4.036587e+04
# low           3.634001e+04
# open          3.684986e+04
# volumefrom    1.240868e+05
# volumeto      4.753170e+09
# close         3.947941e+04
# Name: 2021-01-07 00:00:00, dtype: float64
# high          4.196496e+04
# low           3.664051e+04
# open          3.947941e+04
# volumefrom    1.180773e+05
# volumeto      4.705592e+09
# close         4.063624e+04
# Name: 2021-01-08 00:00:00, dtype: float64
# high          4.140048e+04
# low           3.878361e+04
# open          4.063624e+04
# volumefrom    5.559128e+04
# volumeto      2.241901e+09
# close         4.023666e+04
# Name: 2021-01-09 00:00:00, dtype: float64
# high          4.142788e+04
# low           3.528365e+04
# open          4.023666e+04
# volumefrom    1.032203e+05
# volumeto      3.983391e+09
# close         3.820208e+04
# Name: 2021-01-10 00:00:00, dtype: float64
# high          3.826642e+04
# low           3.030840e+04
# open          3.820208e+04
# volumefrom    2.403280e+05
# volumeto      8.100819e+09
# close         3.549603e+04
# Name: 2021-01-11 00:00:00, dtype: float64
# high          3.662028e+04
# low           3.252298e+04
# open          3.549603e+04
# volumefrom    1.152325e+05
# volumeto      3.999536e+09
# close         3.405840e+04
# Name: 2021-01-12 00:00:00, dtype: float64
# high          3.780967e+04
# low           3.240589e+04
# open          3.405840e+04
# volumefrom    9.197917e+04
# volumeto      3.198683e+09
# close         3.738085e+04
# Name: 2021-01-13 00:00:00, dtype: float64
# high          4.009343e+04
# low           3.675189e+04
# open          3.738085e+04
# volumefrom    7.497221e+04
# volumeto      2.895085e+09
# close         3.915558e+04
# Name: 2021-01-14 00:00:00, dtype: float64
# high          3.969543e+04
# low           3.439619e+04
# open          3.915558e+04
# volumefrom    8.946827e+04
# volumeto      3.288448e+09
# close         3.679017e+04
# Name: 2021-01-15 00:00:00, dtype: float64
# high          3.794244e+04
# low           3.539588e+04
# open          3.679017e+04
# volumefrom    5.422628e+04
# volumeto      1.995054e+09
# close         3.602526e+04
# Name: 2021-01-16 00:00:00, dtype: float64
# high          3.686067e+04
# low           3.385483e+04
# open          3.602526e+04
# volumefrom    5.091330e+04
# volumeto      1.806688e+09
# close         3.583951e+04
# Name: 2021-01-17 00:00:00, dtype: float64
# high          3.742924e+04
# low           3.478440e+04
# open          3.583951e+04
# volumefrom    4.306397e+04
# volumeto      1.554687e+09
# close         3.662304e+04
# Name: 2021-01-18 00:00:00, dtype: float64
# high          3.786753e+04
# low           3.591728e+04
# open          3.662304e+04
# volumefrom    4.845745e+04
# volumeto      1.787957e+09
# close         3.593279e+04
# Name: 2021-01-19 00:00:00, dtype: float64
# high          3.640996e+04
# low           3.351959e+04
# open          3.593279e+04
# volumefrom    6.630202e+04
# volumeto      2.316776e+09
# close         3.550138e+04
# Name: 2021-01-20 00:00:00, dtype: float64
# high          3.561960e+04
# low           3.006714e+04
# open          3.550138e+04
# volumefrom    1.255870e+05
# volumeto      4.042427e+09
# close         3.084030e+04
# Name: 2021-01-21 00:00:00, dtype: float64
# high          3.385739e+04
# low           2.881730e+04
# open          3.084030e+04
# volumefrom    1.092101e+05
# volumeto      3.418228e+09
# close         3.300802e+04
# Name: 2021-01-22 00:00:00, dtype: float64
# high          3.348473e+04
# low           3.143015e+04
# open          3.300802e+04
# volumefrom    3.981332e+04
# volumeto      1.287619e+09
# close         3.210729e+04
# Name: 2021-01-23 00:00:00, dtype: float64
# high          3.309099e+04
# low           3.095756e+04
# open          3.210729e+04
# volumefrom    3.365076e+04
# volumeto      1.079876e+09
# close         3.228366e+04
# Name: 2021-01-24 00:00:00, dtype: float64
# high          3.488118e+04
# low           3.193709e+04
# open          3.228366e+04
# volumefrom    5.952949e+04
# volumeto      1.989618e+09
# close         3.227527e+04
# Name: 2021-01-25 00:00:00, dtype: float64
# high          3.294369e+04
# low           3.085317e+04
# open          3.227527e+04
# volumefrom    5.977006e+04
# volumeto      1.909630e+09
# close         3.251652e+04
# Name: 2021-01-26 00:00:00, dtype: float64
# high          3.258005e+04
# low           2.923673e+04
# open          3.251652e+04
# volumefrom    1.022572e+05
# volumeto      3.149651e+09
# close         3.042305e+04
# Name: 2021-01-27 00:00:00, dtype: float64
# high          3.388092e+04
# low           2.990553e+04
# open          3.042305e+04
# volumefrom    7.699310e+04
# volumeto      2.463162e+09
# close         3.344387e+04
# Name: 2021-01-28 00:00:00, dtype: float64
# high          3.863150e+04
# low           3.199608e+04
# open          3.344387e+04
# volumefrom    1.694546e+05
# volumeto      6.015929e+09
# close         3.425208e+04
# Name: 2021-01-29 00:00:00, dtype: float64
# high          3.490615e+04
# low           3.285800e+04
# open          3.425208e+04
# volumefrom    4.632631e+04
# volumeto      1.574214e+09
# close         3.431782e+04
# Name: 2021-01-30 00:00:00, dtype: float64
# high          3.438170e+04
# low           3.221408e+04
# open          3.431782e+04
# volumefrom    3.533711e+04
# volumeto      1.176982e+09
# close         3.314322e+04
# Name: 2021-01-31 00:00:00, dtype: float64
# high          3.471434e+04
# low           3.234024e+04
# open          3.314322e+04
# volumefrom    4.814460e+04
# volumeto      1.623291e+09
# close         3.353594e+04
# Name: 2021-02-01 00:00:00, dtype: float64
# high          3.600447e+04
# low           3.345948e+04
# open          3.353594e+04
# volumefrom    5.137738e+04
# volumeto      1.789699e+09
# close         3.552443e+04
# Name: 2021-02-02 00:00:00, dtype: float64
# high          3.770480e+04
# low           3.541372e+04
# open          3.552443e+04
# volumefrom    6.397493e+04
# volumeto      2.340630e+09
# close         3.767734e+04
# Name: 2021-02-03 00:00:00, dtype: float64
# high          3.874189e+04
# low           3.619919e+04
# open          3.767734e+04
# volumefrom    7.377545e+04
# volumeto      2.767003e+09
# close         3.698342e+04
# Name: 2021-02-04 00:00:00, dtype: float64
# high          3.834392e+04
# low           3.662650e+04
# open          3.698342e+04
# volumefrom    4.524369e+04
# volumeto      1.705038e+09
# close         3.831024e+04
# Name: 2021-02-05 00:00:00, dtype: float64
# high          4.098911e+04
# low           3.824796e+04
# open          3.831024e+04
# volumefrom    6.649460e+04
# volumeto      2.642530e+09
# close         3.926701e+04
# Name: 2021-02-06 00:00:00, dtype: float64
# high          3.972159e+04
# low           3.740816e+04
# open          3.926701e+04
# volumefrom    5.382340e+04
# volumeto      2.076905e+09
# close         3.886882e+04
# Name: 2021-02-07 00:00:00, dtype: float64
# high          4.660682e+04
# low           3.806387e+04
# open          3.886882e+04
# volumefrom    1.384852e+05
# volumeto      5.944522e+09
# close         4.643741e+04
# Name: 2021-02-08 00:00:00, dtype: float64
# high          4.820959e+04
# low           4.505146e+04
# open          4.643741e+04
# volumefrom    9.867048e+04
# volumeto      4.610215e+09
# close         4.650957e+04
# Name: 2021-02-09 00:00:00, dtype: float64
# high          4.734986e+04
# low           4.374399e+04
# open          4.650957e+04
# volumefrom    7.299280e+04
# volumeto      3.326891e+09
# close         4.485495e+04
# Name: 2021-02-10 00:00:00, dtype: float64
# high          4.866481e+04
# low           4.403266e+04
# open          4.485495e+04
# volumefrom    7.225182e+04
# volumeto      3.377368e+09
# close         4.800618e+04
# Name: 2021-02-11 00:00:00, dtype: float64
# high          4.893099e+04
# low           4.624385e+04
# open          4.800618e+04
# volumefrom    5.954961e+04
# volumeto      2.831635e+09
# close         4.743554e+04
# Name: 2021-02-12 00:00:00, dtype: float64
# high          4.817146e+04
# low           4.629119e+04
# open          4.743554e+04
# volumefrom    3.328125e+04
# volumeto      1.571325e+09
# close         4.722232e+04
# Name: 2021-02-13 00:00:00, dtype: float64
# high          4.964239e+04
# low           4.709692e+04
# open          4.722232e+04
# volumefrom    3.785359e+04
# volumeto      1.841963e+09
# close         4.865287e+04
# Name: 2021-02-14 00:00:00, dtype: float64
# high          4.903174e+04
# low           4.591000e+04
# open          4.865287e+04
# volumefrom    5.268357e+04
# volumeto      2.502098e+09
# close         4.793651e+04
# Name: 2021-02-15 00:00:00, dtype: float64
# high          5.056153e+04
# low           4.706863e+04
# open          4.793651e+04
# volumefrom    6.607259e+04
# volumeto      3.237085e+09
# close         4.918463e+04
# Name: 2021-02-16 00:00:00, dtype: float64
# high          5.262268e+04
# low           4.896772e+04
# open          4.918463e+04
# volumefrom    6.713349e+04
# volumeto      3.423930e+09
# close         5.215491e+04
# Name: 2021-02-17 00:00:00, dtype: float64

# %%
model = build_lstm_model(
    X_train, output_size=1, neurons=lstm_neurons, dropout=dropout, loss=loss,
    optimizer=optimizer)

#X_train = np.asarray(X_train).astype(np.float32)
history = model.fit(
    X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=1, shuffle=True)
# Out:
# Epoch 1/50
# 449/449 [==============================] - 7s 3ms/step - loss: 0.1731
# Epoch 2/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0747
# Epoch 3/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0626
# Epoch 4/50
# 449/449 [==============================] - 1s 3ms/step - loss: 0.0548
# Epoch 5/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0498
# Epoch 6/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0478
# Epoch 7/50
# 449/449 [==============================] - 1s 3ms/step - loss: 0.0421
# Epoch 8/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0401
# Epoch 9/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0392
# Epoch 10/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0393
# Epoch 11/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0383
# Epoch 12/50
# 449/449 [==============================] - 1s 3ms/step - loss: 0.0360
# Epoch 13/50
# 449/449 [==============================] - 1s 3ms/step - loss: 0.0362
# Epoch 14/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0345
# Epoch 15/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0359
# Epoch 16/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0367
# Epoch 17/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0350
# Epoch 18/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0350
# Epoch 19/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0338
# Epoch 20/50
# 449/449 [==============================] - 1s 3ms/step - loss: 0.0356
# Epoch 21/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0334
# Epoch 22/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0344
# Epoch 23/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0330
# Epoch 24/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0341
# Epoch 25/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0354
# Epoch 26/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0322
# Epoch 27/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0327
# Epoch 28/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0336
# Epoch 29/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0336
# Epoch 30/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0348
# Epoch 31/50
# 449/449 [==============================] - 1s 3ms/step - loss: 0.0338
# Epoch 32/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0347
# Epoch 33/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0325
# Epoch 34/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0333
# Epoch 35/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0320
# Epoch 36/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0343
# Epoch 37/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0317
# Epoch 38/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0320
# Epoch 39/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0313
# Epoch 40/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0314
# Epoch 41/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0317
# Epoch 42/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0338
# Epoch 43/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0324
# Epoch 44/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0330
# Epoch 45/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0324
# Epoch 46/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0331
# Epoch 47/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0324
# Epoch 48/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0320
# Epoch 49/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0314
# Epoch 50/50
# 449/449 [==============================] - 1s 2ms/step - loss: 0.0311

# %% [markdown]
# ## Plot predictions

# %%
targets = test[target_col][window_len:]
preds = model.predict(X_test).squeeze()

# %%
mean_absolute_error(preds, y_test)
# Out:
# 0.05184208095350645

# %%
# 0.045261384613638447 with mae

# %%
preds = test[target_col].values[:-window_len] * (preds + 1)
preds = pd.Series(index=targets.index, data=preds)

line_plot(targets, preds, 'actual', 'prediction', lw=3)

# %%
n_points = 30

line_plot(targets[-n_points:], preds[-n_points:], 'actual', 'prediction', lw=3)

# %%
line_plot(targets[-n_points:][:-1], preds[-n_points:].shift(-1), 'actual', 'prediction', lw=3)

# %% [markdown]
# ## Compare returns

# %%
actual_returns = targets.pct_change()[1:]
predicted_returns = preds.pct_change()[1:]

# %%
def dual_line_plot(line1, line2, line3, line4, label1=None, label2=None, title='', lw=2):
    import matplotlib.dates as mdates
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(21, 9))
    ax1.plot(line1, label=label1, linewidth=lw)
    ax1.plot(line2, label=label2, linewidth=lw)
    ax2.plot(line3, label=label1, linewidth=lw)
    ax2.plot(line4, label=label2, linewidth=lw)
    ax2.set_xticks(ax1.get_xticks())
    ax2.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
    ax1.set_ylabel('daily returns', fontsize=14)
    ax2.legend(loc='best', fontsize=18);

# %%
dual_line_plot(actual_returns[-n_points:],
          predicted_returns[-n_points:],
          actual_returns[-n_points:][:-1],
          predicted_returns[-n_points:].shift(-1),
          'actual returns', 'predicted returns', lw=3)

# %%
line_plot(actual_returns[-n_points:][:-1], predicted_returns[-n_points:].shift(-1),
           'actual returns', 'predicted returns', lw=3)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 9))

# actual correlation
corr = np.corrcoef(actual_returns, predicted_returns)[0][1]
ax1.scatter(actual_returns, predicted_returns, color='k', marker='o', alpha=0.5, s=100)
ax1.set_title('r = {:.2f}'.format(corr), fontsize=18)

# shifted correlation
shifted_actual = actual_returns[:-1]
shifted_predicted = predicted_returns.shift(-1).dropna()
corr = np.corrcoef(shifted_actual, shifted_predicted)[0][1]
ax2.scatter(shifted_actual, shifted_predicted, color='k', marker='o', alpha=0.5, s=100)
ax2.set_title('r = {:.2f}'.format(corr), fontsize=18);
